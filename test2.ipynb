# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai
load_dotenv('conf/.env',override=True)
# Out:
# True

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    length_function=len
)

# %%
churchill_speech=''
with open('data/churchill_speech.txt') as f:
    churchill_speech=f.read();

chunks=text_splitter.create_documents([churchill_speech])

# %%
print(type(chunks))
print(type(chunks[0]))
print(chunks[0])
print(chunks[10].page_content)
print(len(chunks))
# Out:
# <class 'list'>
# <class 'langchain_core.documents.base.Document'>
# page_content='From the moment that the French defenses at Sedan and on the Meuse were broken at the end of the'
# Belgium to keep on holding the right hand of the Belgians and to give their own right hand to a
# 298

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai import GoogleGenerativeAI
x=GoogleGenerativeAI(model='models/embedding-001')
x.get_num_tokens(chunks[0].page_content)
# llm=GoogleGenerativeAIEmbeddings(model="text-embedding-004")
# llm.get_num_tokens(chunks[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[15], line 3
#       1 from langchain_google_genai import GoogleGenerativeAIEmbeddings
#       2 from langchain_google_genai import GoogleGenerativeAI
# ----> 3 x=GoogleGenerativeAI(model='models/embedding-001')
#       4 x.get_num_tokens(chunks[0].page_content)
#       5 # llm=GoogleGenerativeAIEmbeddings(model="text-embedding-004")
#       6 # llm.get_num_tokens(chunks[0].page_content)
#
# File C:\IDE\PycharmProjects\Langchain\venv\Lib\site-packages\langchain_core\load\serializable.py:125, in Serializable.__init__(self, *args, **kwargs)
#     123 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124     """"""
# --> 125     super().__init__(*args, **kwargs)
#
# File C:\IDE\PycharmProjects\Langchain\venv\Lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
# ...
